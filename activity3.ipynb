# %% [markdown]
# <h1>UK ROAD ACCIDENT DATA ANALYSIS</h1>
# <h2>INCLUSIVE YEAR 2019 - 2022</h2>

# %% [markdown]
# <h3>Analyst : Ryom James Alemania</h3>

# %% [markdown]
# <h3>DATA PREPERATION</h3>
# <p>Transfering Data set to folder</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

# %% [markdown]
# <h1>IMPORTING DATASET TO DATA FRAME</h1>

# %%
accidents = pd.read_csv('datasets\\accident_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 accidents = pd.read_csv('datasets\\accident_data.csv')
#
# ...

# %%
accidents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 accidents
#
# NameError: name 'accidents' is not defined

# %% [markdown]
# <h1>Checking your DATA FRAME for null values, and data types</h1>

# %%
accidents.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 accidents.describe()
#
# NameError: name 'accidents' is not defined

# %% [markdown]
# <h1>Deleteing rows & Fill empty cells with a value</h1>

# %%
accidents['Latitude'] = accidents['Latitude'].fillna(accidents['Latitude'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 accidents['Latitude'] = accidents['Latitude'].fillna(accidents['Latitude'].mean())
#
# NameError: name 'accidents' is not defined

# %%
accidents['Longitude'] = accidents['Longitude'].fillna(accidents['Longitude'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 accidents['Longitude'] = accidents['Longitude'].fillna(accidents['Longitude'].mean())
#
# NameError: name 'accidents' is not defined

# %%
#accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].fillna(accidents['Road_Surface_Conditions'].mode()[0])

# %%
#accidents['Road_Type'] = accidents['Road_Type'].fillna(accidents['Road_Type'].mode()[0])

# %%
#accidents['Weather_Conditions'] = accidents['Weather_Conditions'].fillna(accidents['Weather_Conditions'].mode()[0])

# %%
accidents['Urban_or_Rural_Area'] = accidents['Urban_or_Rural_Area'].fillna(accidents['Urban_or_Rural_Area'].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 accidents['Urban_or_Rural_Area'] = accidents['Urban_or_Rural_Area'].fillna(accidents['Urban_or_Rural_Area'].mode()[0])
#
# NameError: name 'accidents' is not defined

# %%
accidents.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 accidents.isnull().sum()
#
# NameError: name 'accidents' is not defined

# %% [markdown]
# <h1>Converting date Field into DATE TIME data type</h1>

# %%
accidents['Accident_Severity'] = accidents['Accident_Severity'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 accidents['Accident_Severity'] = accidents['Accident_Severity'].astype('category')
#
# NameError: name 'accidents' is not defined

# %%
accidents['Light_Conditions'] = accidents['Light_Conditions'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 accidents['Light_Conditions'] = accidents['Light_Conditions'].astype('category')
#
# NameError: name 'accidents' is not defined

# %%
accidents['District Area'] = accidents['District Area'].astype('category')

# %%
accidents['Road_Surface_Conditions'] = accidents['Road_Surface_Conditions'].astype('category')

# %%
accidents['Road_Type'] = accidents['Road_Type'].astype('category')

# %%
accidents['Urban_or_Rural_Area'] = accidents['Urban_or_Rural_Area'].astype('category')

# %%
accidents['Weather_Conditions'] = accidents['Weather_Conditions'].astype('category')

# %%
accidents['Vehicle_Type'] = accidents['Vehicle_Type'].astype('category')

# %%
accidents.dtypes

# %% [markdown]
# <h1>DATA INSIGHTS</h1>

# %% [markdown]
# <h1>1. DO CRASHES WITH MORE CARS INVOLVE MORE CASUALTIES?</h1>

# %%
vehicles_casualties = accidents['Number_of_Vehicles'].corr(accidents['Number_of_Casualties'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 vehicles_casualties = accidents['Number_of_Vehicles'].corr(accidents['Number_of_Casualties'])
#
# NameError: name 'accidents' is not defined

# %%
vehicles_casualties
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 vehicles_casualties
#
# NameError: name 'vehicles_casualties' is not defined

# %% [markdown]
# <h1>Insight No. 1</h1>
# <h1>CRASHES WITH MULTIPLE CARS DON'T ALWAYS MEAN MORE CASUALTIES.</h1>

# %% [markdown]
# <h1>2. WHICH DISTRICTS HAVE THE MOST DEADLY ACCIDENTS?</h1>

# %%
severity_district = accidents[accidents['Accident_Severity'] == 'Fatal']['District Area'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 severity_district = accidents[accidents['Accident_Severity'] == 'Fatal']['District Area'].value_counts()
#
# NameError: name 'accidents' is not defined

# %%
severity_district
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 severity_district
#
# NameError: name 'severity_district' is not defined

# %% [markdown]
# <h1>Insight No. 2</h1>
# <h2>BIRMINGHAM HAS THE MOST FATAL ACCIDENTS WITH 105 REPORTED, FOLLOWED BY LEEDS WITH 93 AND HIGHLAND WITH 88.</h2>

# %% [markdown]
# <h1>3. WHICH TYPE OF VEHICLE IS INVOLVED IN THE MOST DEADLY ACCIDENTS?</h1>

# %%
severity_vtype = accidents[accidents['Accident_Severity'] == 'Fatal']['Vehicle_Type'].value_counts()

# %%
severity_vtype

# %% [markdown]
# <h1>Insight No. 3</h1>
# <h2>CARS ARE INVOLVED IN THE MOST FATAL ACCIDENTS, WITH 6,577 REPORTED.</h2>

# %% [markdown]
# <h1>4. HOW DOES ROAD TYPE AFFECT HOW SEVERE AN ACCIDENT IS?</h1>

# %%
rtype_severity = accidents.groupby('Road_Type')['Accident_Severity'].value_counts()

# %%
rtype_severity

# %% [markdown]
# <h1>Insight No. 4</h1>
# <h2>SINGLE CARRIAGEWAYS HAVE THE MOST ACCIDENTS, WITH 415,557 SLIGHT, 70,059 SERIOUS, AND 6,527 FATAL REPORTED.</h2>

# %% [markdown]
# <h1>5. DOES THE NUMBER OF VEHICLES INVOLVED IMPACT HOW SEVERE AN ACCIDENT IS?</h1>

# %%
severity_vehicles = np.round(accidents.groupby('Accident_Severity')['Number_of_Casualties'].mean(), 0)

# %%
severity_vehicles

# %% [markdown]
# <h1>Insight No. 5</h1>
# <h2>SLIGHT ACCIDENTS INVOLVE THE MOST VEHICLES ON AVERAGE (2), WHILE FATAL AND SERIOUS ACCIDENTS USUALLY INVOLVE 1 VEHICLE.</h2>

# %% [markdown]
# <h1>6. HOW DO LIGHT CONDITIONS AFFECT HOW SEVERE AN ACCIDENT IS?</h1>

# %%
light_severity = accidents.groupby('Light_Conditions')['Accident_Severity'].value_counts()

# %%
light_severity

# %% [markdown]
# <h1>Insight No. 6</h1>
# <h2>MOST ACCIDENTS HAPPEN IN DAYLIGHT, WITH 419,045 SLIGHT, 60,759 SERIOUS, AND 5,076 FATAL REPORTED.</h2>

# %% [markdown]
# <h1>7. HOW DOES URBAN OR RURAL CLASSIFICATION AFFECT ACCIDENT SEVERITY?</h1>

# %%
area_severity = accidents.groupby('Urban_or_Rural_Area')['Accident_Severity'].value_counts()

# %%
area_severity

# %% [markdown]
# <h1>Insight No. 7</h1>
# <h2>URBAN AREAS HAVE MORE ACCIDENTS BUT FEWER FATALITIES, WITH 367,714 SLIGHT, 50,904 SERIOUS, AND 3,060 FATAL REPORTED. RURAL AREAS HAVE FEWER ACCIDENTS BUT A HIGHER FATALITY RATE, WITH 196,077 SLIGHT, 37,312 SERIOUS, AND 5,601 FATAL REPORTED.</h2>

# %% [markdown]
# <h1>8. WHICH ROAD SURFACE CONDITION IS MOST COMMON IN FATAL ACCIDENTS?</h1>

# %%
severity_rtype = accidents[accidents['Accident_Severity'] == 'Fatal']['Road_Surface_Conditions'].mode()[0]

# %%
severity_rtype

# %% [markdown]
# <h1>Insight No. 8</h1>
# <h2>MOST FATAL ACCIDENTS HAPPEN ON DRY ROADS.</h2>

# %% [markdown]
# <h1>9. HOW DOES WEATHER AFFECT ACCIDENT SEVERITY?</h1>

# %%
severity_weather = accidents.groupby('Weather_Conditions')['Accident_Severity'].value_counts()

# %%
severity_weather

# %% [markdown]
# <h1>Insight No. 9</h1>
# <h2>MOST ACCIDENTS HAPPEN IN "FINE NO HIGH WINDS" CONDITIONS, WITH 441,739 SLIGHT, 72,046 SERIOUS, AND 7,100 FATAL REPORTED.</h2>

# %% [markdown]
# <h1>10. WHICH DISTRICT HAS THE MOST ACCIDENTS AT NIGHT?</h1>

# %%
district_nighttime = accidents[accidents['Light_Conditions'] != 'Daylight']['District Area'].value_counts()

# %%
district_nighttime

# %% [markdown]
# <h1>Insight No. 10</h1>
# <h2>BIRMINGHAM HAS THE MOST NIGHTTIME ACCIDENTS, WITH 3,824 REPORTED.</h2>

# %% [markdown]
# <h1>11. HOW MANY ACCIDENTS HAPPEN ON WEEKENDS COMPARED TO WEEKDAYS?</h1>

# %%
weekends = (accidents['Accident Date'].dt.dayofweek >= 5).mean() * 100

# %%
weekends

# %% [markdown]
# <h1>Insight No. 11</h1>
# <h2>11.84% OF ALL ACCIDENTS HAPPEN ON WEEKENDS.</h2>

# %% [markdown]
# <h1>12. HOW DO WEATHER CONDITIONS AFFECT THE NUMBER OF CASUALTIES?</h1>

# %%
weather_casualties = np.round(accidents.groupby('Weather_Conditions')['Number_of_Casualties'].mean(), 1)

# %%
weather_casualties

# %% [markdown]
# <h1>Insight No. 12</h1>
# <h2>FOGGY OR MISTY WEATHER HAS THE HIGHEST CASUALTY RATE AT 1.5 PER ACCIDENT.</h2>

# %% [markdown]
# <h1>13. HOW DOES ROAD TYPE AFFECT THE NUMBER OF VEHICLES INVOLVED IN ACCIDENTS?</h1>

# %%
rtype_vehicles = np.round(accidents.groupby('Road_Type')['Number_of_Vehicles'].mean(), 1)

# %%
rtype_vehicles

# %% [markdown]
# <h1>Insight No. 13</h1>
# <h2>DUAL CARRIAGEWAYS HAVE THE HIGHEST AVERAGE NUMBER OF VEHICLES PER ACCIDENT, WITH 2 INVOLVED.</h2>

# %% [markdown]
# <h1>14. WHICH DISTRICT HAS THE MOST ACCIDENTS DURING DAYLIGHT?</h1>

# %%
district_daylight = accidents[accidents['Light_Conditions'] == 'Daylight']['District Area'].value_counts()

# %%
district_daylight

# %% [markdown]
# <h1>Insight No. 14</h1>
# <h2>BIRMINGHAM HAS THE MOST DAYLIGHT ACCIDENTS, WITH 9,667 REPORTED.</h2>

# %% [markdown]
# <h1>15. HOW ARE ACCIDENT-PRONE AREAS CLUSTERED BASED ON LATITUDE AND LONGITUDE?</h1>

# %%
long_lat = accidents[['Latitude', 'Longitude']].value_counts()

# %%
long_lat

# %% [markdown]
# <h1>Insight No. 15</h1>
# <h2>THE HIGHEST ACCIDENT COUNT (45) OCCURS AT LATITUDE 52.949719, LONGITUDE -0.977611.</h2>

# %% [markdown]
# <h1>16. WHAT PERCENTAGE OF ACCIDENTS HAPPEN ON WEEKDAYS?</h1>

# %%
weekdays = (accidents['Accident Date'].dt.dayofweek < 5).mean() * 100

# %%
weekdays

# %% [markdown]
# <h1>Insight No. 16</h1>
# <h2>28.27% OF ALL ACCIDENTS HAPPEN ON WEEKDAYS.</h2>

# %% [markdown]
# <h1>17. WHICH DAY OF THE WEEK HAS THE MOST ACCIDENTS?</h1>

# %%
accident_day = accidents['Accident Date'].dt.day_name().value_counts()

# %%
accident_day

# %% [markdown]
# <h1>Insight No. 17</h1>
# <h2>SATURDAY HAS THE MOST ACCIDENTS (43,164), FOLLOWED BY WEDNESDAY (40,037) AND FRIDAY (39,822).</h2>

# %% [markdown]
# <h1>18. WHAT IS THE HIGHEST NUMBER OF CASUALTIES RECORDED IN A SINGLE-VEHICLE ACCIDENT?</h1>

# %%
casualties_single = accidents[accidents['Number_of_Vehicles'] == 1]['Number_of_Casualties'].max()

# %%
casualties_single

# %% [markdown]
# <h1>Insight No. 18</h1>
# <h2>THE HIGHEST NUMBER OF CASUALTIES IN A SINGLE-VEHICLE ACCIDENT IS 68.</h2>

# %% [markdown]
# <h1>19. WHICH ROAD TYPE HAS THE MOST FATAL ACCIDENTS?</h1>

# %%
rtype_fatal = accidents[accidents['Accident_Severity'] == 'Fatal']['Road_Type'].value_counts()

# %%
rtype_fatal

# %% [markdown]
# <h1>Insight No. 19</h1>
# <h2>SINGLE CARRIAGEWAYS HAVE THE MOST FATAL ACCIDENTS, WITH 6,527 REPORTED.</h2>

# %% [markdown]
# <h1>20. HOW DOES THE AVERAGE NUMBER OF VEHICLES INVOLVED DIFFER BETWEEN DRY AND WET ROADS?</h1>

# %%
vehicles_roadcon = np.round(accidents.groupby('Road_Surface_Conditions')['Number_of_Vehicles'].mean(), 1)

# %%
vehicles_roadcon

# %% [markdown]
# <h1>Insight No. 20</h1>
# <h2>ACCIDENTS ON BOTH DRY AND WET ROADS INVOLVE AN AVERAGE OF 1.8 VEHICLES, SHOWING NO SIGNIFICANT DIFFERENCE BASED ON ROAD CONDITIONS.</h2>

# %%
accidents.dtypes
